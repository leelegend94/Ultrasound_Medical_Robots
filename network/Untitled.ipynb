# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms

from modules.UNet import *
from modules.Discriminator import *
from modules.DataSet import *
from modules.Losses import *

import os,sys

from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
from PIL import Image

import numpy as np

# %% [markdown]
# ## Training

# %%
def train_adversarial(net,discriminator,device,val_per=0.1,epochs=10,batch_size=10,resize_to=None):
    if resize_to is not None:
        transform_image = transforms.Compose([
        transforms.Resize(resize_to),
        transforms.ToTensor(),
        transforms.Normalize(0.5,0.5)
        ])
        transform_label = transforms.Compose([
        transforms.Resize(resize_to),
        transforms.ToTensor()
        ])
    else:
        transform_image = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(0.5,0.5)
        ])
        transform_label = transforms.Compose([
        transforms.ToTensor()
        ])
            
    
    dataSet = UltraSoundDataSet(root_dir,(transform_image,transform_label))
    nTrain = int(len(dataSet)*(1-val_per))
    nValid = int(len(dataSet)-nTrain)
    
    trainSet,validSet = random_split(dataSet,[nTrain,nValid])
    
    train_loader = DataLoader(trainSet,batch_size=batch_size,shuffle=True,num_workers=4)
    valid_loader = DataLoader(validSet,batch_size=batch_size,shuffle=True,num_workers=4)
    
    optimizer_unet = torch.optim.Adam(net.parameters())
    optimizer_disc = torch.optim.Adam(discriminator.parameters())
    scheduler_unet = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_unet,mode='min',patience=10) #mae: dice-index
    scheduler_disc = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_disc,mode='min',patience=10)
    BCELoss = nn.BCELoss()
    
    running_loss_seg = 0
    running_loss_disc = 0
    step = 0
    np.set_printoptions(precision=2)
    for epoch in range(epochs):
        net.train()
        discriminator.train()
        
        for batch in train_loader:
            imgs,labels = batch
            
            imgs = imgs.to(device=device,dtype=torch.float32)
            labels = labels.to(device=device,dtype=torch.float32)
            
            # segmentation network
            pred = net(imgs)
            
            # discriminator network
            pred_valid = discriminator(imgs, labels)
            pred_fake = discriminator(imgs, pred.detach())   
            print("valid: ",np.array(pred_valid.view([1,-1]).tolist()),"; fake: ",np.array(pred_fake.view([1,-1]).tolist()) )
            # seg loss
            #seg_loss = DiceLoss(pred,labels)
            seg_loss = BCELoss(pred,labels)
            
            if epoch<epochs/2:
                optimizer_unet.zero_grad()
                seg_loss.backward(retain_graph=True)
                optimizer_unet.step()
            
            
            valid = torch.Tensor(imgs.size(0), 1).fill_(1.0).to(device=device,dtype=torch.float32)
            fake = torch.Tensor(imgs.size(0), 1).fill_(0.0).to(device=device,dtype=torch.float32)
            
            # discriminator loss
            disc_loss = BCELoss(pred_valid,valid) + BCELoss(pred_fake,fake)

            optimizer_disc.zero_grad()
            disc_loss.backward(retain_graph=False)
            optimizer_disc.step()
            
            running_loss_seg += seg_loss.item()
            running_loss_disc += disc_loss.item()
            step += 1
            
            if step % 10 == 9:    # print every 10 mini-batches
                print('[%d, %5d] segmentation loss: %.3f; discrimination loss: %.3f' %(epoch + 1, step + 1, running_loss_seg / 10, running_loss_disc / 10))
                running_loss_seg = 0.0
                running_loss_disc = 0.0
                
            if step%100 == 99:
                val_loss_seg = 0
                val_loss_disc = 0
                for batch in valid_loader:
                    imgs,labels = batch
                    imgs = imgs.to(device=device,dtype=torch.float32)
                    labels = labels.to(device=device,dtype=torch.float32)
                    
                    with torch.no_grad():
                        pred_seg = net(imgs)
                        pred_valid = discriminator(imgs, labels)
                        pred_fake = discriminator(imgs, pred_seg.detach())
                    
                    val_loss_seg += DiceLoss(pred_seg,labels).item()
                    valid = torch.Tensor(imgs.size(0), 1).fill_(1.0).to(device=device,dtype=torch.float32)
                    fake = torch.Tensor(imgs.size(0), 1).fill_(0.0).to(device=device,dtype=torch.float32)
                    val_loss_disc += (BCELoss(pred_valid,valid) + BCELoss(pred_fake,fake)).item()
                print('[%d, %5d] validation loss(seg): %.3f; validation loss(disc): %.3f' %(epoch + 1, step + 1, val_loss_seg / len(valid_loader), val_loss_disc / len(valid_loader)))
                scheduler_unet.step(val_loss_seg)
                scheduler_disc.step(val_loss_disc)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = UNet2(init_features=32)
discriminator = Discriminator()

net = net.to(device)
discriminator = discriminator.to(device)

#IMG_SIZE = [256,256]
IMG_SIZE = None

root_dir = os.path.expanduser("~/workspace/us_robot/DataSet/SimRealDataset")
try:
    #train(net=net,device=device,resize_to=None,epochs=50,batch_size=5)
    train_adversarial(net=net,discriminator=discriminator,device=device,resize_to=IMG_SIZE,epochs=5,batch_size=3)
except KeyboardInterrupt:
    sys.exit()
# Out:
# valid:  [[0.52 0.52 0.52]] ; fake:  [[0.52 0.52 0.52]]
# valid:  [[0.86 0.86 0.86]] ; fake:  [[0.63 0.63 0.63]]
# valid:  [[0.28 0.32 0.33]] ; fake:  [[0.1  0.09 0.1 ]]
# valid:  [[0.92 0.92 0.92]] ; fake:  [[0.28 0.3  0.3 ]]
# valid:  [[0.98 0.8  0.98]] ; fake:  [[0.36 0.33 0.36]]
# valid:  [[0.99 0.99 0.99]] ; fake:  [[0.17 0.16 0.17]]
# valid:  [[0.99 0.99 0.79]] ; fake:  [[0.04 0.03 0.03]]
# valid:  [[0.99 0.99 0.99]] ; fake:  [[0.01 0.01 0.01]]
# valid:  [[0.99 0.99 0.99]] ; fake:  [[0. 0. 0.]]
# [1,    10] segmentation loss: 0.616; discrimination loss: 0.510
# valid:  [[0.99 0.97 0.99]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1.   1.   0.99]] ; fake:  [[7.66e-05 7.87e-05 7.71e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.98e-05 3.53e-05 2.16e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.99e-05 1.98e-05 5.18e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-05 8.69e-06 3.61e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.76e-06 1.43e-05 1.51e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.31e-05 7.24e-06 2.43e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.70e-06 1.79e-06 4.51e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.84e-05 5.80e-06 7.90e-06]]
# [1,    20] segmentation loss: 0.509; discrimination loss: 0.002
# valid:  [[1. 1. 1.]] ; fake:  [[1.45e-06 2.08e-06 4.32e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.82e-06 1.29e-06 1.20e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-06 5.54e-07 4.29e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.25e-06 1.87e-06 7.46e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.81e-07 4.54e-07 1.77e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.46e-07 4.72e-07 3.10e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.95e-06 1.29e-06 1.24e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.64e-07 1.18e-06 1.09e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.99e-07 1.40e-06 1.42e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.70e-05 1.14e-05 1.14e-05]]
# [1,    30] segmentation loss: 0.453; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.30e-05 2.37e-06 2.95e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.66e-06 3.53e-06 1.04e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.37e-05 1.81e-05 4.39e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.08e-05 6.72e-05 1.13e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.87e-05 4.78e-06 4.26e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.65e-05 1.80e-05 8.07e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.54e-05 1.26e-04 1.28e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.23e-04 1.39e-05 1.73e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# [1,    40] segmentation loss: 0.398; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.70e-05 1.10e-05 8.24e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.43e-05 6.69e-05 6.87e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.16e-05 5.91e-05 8.34e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.06e-05 1.08e-04 1.11e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.94e-04 3.57e-05 4.12e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.57e-05 2.85e-05 2.65e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.18e-04 2.66e-04 3.73e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.70e-05 1.28e-05 7.84e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.60e-04 2.41e-04 3.51e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.78e-04 4.41e-05 8.89e-05]]
# [1,    50] segmentation loss: 0.363; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.90e-04 1.09e-03 8.53e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.87e-05 8.03e-05 2.22e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.54e-05 9.12e-05 4.22e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.73e-05 4.63e-05 8.87e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.12e-03 4.23e-04 8.57e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.25e-04 3.67e-05 1.14e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.01e-05 3.78e-05 3.68e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.37e-04 5.38e-04 4.12e-05]]
# [1,    60] segmentation loss: 0.328; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.07e-05 2.18e-05 4.76e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.   0.01 0.  ]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.86e-04 7.68e-05 3.40e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.25e-05 5.38e-05 5.42e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.05e-06 6.67e-05 5.67e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.30e-06 2.18e-07 2.19e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.22e-07 1.26e-06 1.25e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.61e-07 1.08e-05 6.31e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.50e-07 1.72e-04 1.86e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.36e-06 1.81e-06 2.58e-07]]
# [1,    70] segmentation loss: 0.302; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.04e-08 6.98e-08 2.09e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.51e-08 1.64e-07 9.02e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.63e-07 5.83e-08 1.38e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-06 1.90e-06 1.14e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.87e-07 1.76e-07 6.69e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.99e-07 1.54e-06 4.05e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.39e-07 2.51e-07 7.13e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.70e-07 6.58e-07 2.50e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.20e-07 9.08e-08 2.63e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.10e-07 1.21e-06 3.16e-06]]
# [1,    80] segmentation loss: 0.282; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[6.78e-07 1.76e-06 1.01e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.74e-08 2.37e-08 2.04e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.36e-07 5.08e-07 2.89e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.59e-07 1.21e-07 7.68e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.15e-08 1.37e-07 3.50e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.30e-08 1.62e-06 4.81e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.41e-08 9.25e-08 3.00e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.76e-07 1.65e-07 1.92e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.61e-08 4.54e-08 7.27e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.28e-07 3.45e-07 1.69e-06]]
# [1,    90] segmentation loss: 0.257; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[9.17e-06 4.90e-06 2.89e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.40e-07 4.37e-07 7.95e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.35e-05 6.59e-06 5.33e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.61e-07 2.96e-07 1.10e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.97e-06 3.62e-06 3.78e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.68e-06 1.55e-05 1.55e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.93e-05 4.78e-06 2.55e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.81e-05 1.54e-04 1.11e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.63e-06 8.62e-06 3.69e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.19e-05 9.63e-04 5.21e-05]]
# [1,   100] segmentation loss: 0.236; discrimination loss: 0.000
# [1,   100] validation loss(seg): 0.957; validation loss(disc): 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.49e-06 4.55e-06 3.23e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.89e-04 1.59e-04 1.72e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.40e-05 3.45e-05 3.48e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.07e-04 2.29e-04 2.96e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.47e-05 4.12e-05 3.39e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.87e-05 5.37e-05 2.47e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.98e-06 1.23e-05 1.16e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.87e-06 1.73e-05 1.13e-05]]
# [1,   110] segmentation loss: 0.220; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[8.72e-06 1.24e-04 1.24e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.47e-06 5.78e-06 1.18e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.99e-06 1.66e-05 6.70e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.16e-06 7.58e-06 7.47e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.36e-06 6.17e-05 2.17e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.77e-06 1.64e-05 2.21e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.95e-06 1.68e-05 8.19e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.76e-05 1.85e-05 1.93e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.29e-06 7.70e-06 9.89e-06]]
# [1,   120] segmentation loss: 0.205; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.64e-06 4.93e-06 3.48e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.10e-06 2.99e-05 4.28e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.71e-06 4.37e-06 5.01e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.71e-06 1.98e-05 2.61e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.14e-05 4.31e-06 1.49e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.86e-05 7.71e-06 4.78e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.53e-05 2.28e-05 3.86e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.57e-06 3.09e-05 9.22e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.32e-05 1.02e-05 1.42e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.53e-05 5.55e-05 1.33e-05]]
# [1,   130] segmentation loss: 0.189; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.08e-05 4.82e-05 1.92e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.76e-05 7.45e-05 3.32e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.38e-05 4.04e-05 2.19e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.65e-03 1.75e-03 9.15e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.32e-04 3.89e-05 3.88e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.55e-05 1.02e-04 2.61e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.51e-05 1.34e-05 2.50e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.83e-06 1.25e-05 3.59e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.84e-04 5.67e-05 1.17e-05]]
# [1,   140] segmentation loss: 0.179; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[9.48e-06 2.54e-05 6.32e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.10e-06 4.06e-06 5.22e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.79e-05 1.85e-06 2.46e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.65e-06 4.26e-06 8.17e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.70e-05 1.17e-05 1.26e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.19e-05 3.76e-06 5.46e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.96e-06 2.98e-06 1.91e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.53e-05 6.66e-06 1.54e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.67e-06 1.34e-05 3.97e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.02e-06 4.42e-05 6.45e-06]]
# [1,   150] segmentation loss: 0.167; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.82e-05 1.08e-04 5.23e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.51e-05 3.56e-05 6.43e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.03e-04 6.75e-05 3.12e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.75e-05 2.89e-04 1.73e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.71e-05 1.61e-05 4.95e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.27e-05 7.20e-05 1.57e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.59e-05 6.10e-05 7.09e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.29e-04 4.78e-05 2.07e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.28e-04 6.29e-05 3.49e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# [1,   160] segmentation loss: 0.157; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.87e-04 6.69e-05 2.66e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.05e-05 8.53e-05 4.81e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.47e-04 4.05e-05 5.80e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.26e-05 1.15e-04 6.57e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.91e-05 4.78e-05 1.22e-04]]
# valid:  [[1.  0.9 1. ]] ; fake:  [[3.79e-04 4.04e-05 4.17e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.23 0.35 0.32]]
# valid:  [[0.73 0.97 0.98]] ; fake:  [[5.56e-10 3.82e-09 3.76e-09]]
# [1,   170] segmentation loss: 0.144; discrimination loss: 0.052
# valid:  [[0.99 1.   0.91]] ; fake:  [[5.06e-12 1.14e-10 3.66e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.87e-11 5.70e-11 4.64e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.54e-08 1.05e-06 1.21e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.97e-05 9.08e-07 1.40e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.01 0.64 0.  ]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.28e-04 6.21e-04 3.84e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.38e-09 1.27e-09 1.06e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.39e-14 4.48e-14 8.09e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.10e-18 5.70e-18 1.23e-18]]
# valid:  [[0.13 1.   0.04]] ; fake:  [[4.67e-21 4.98e-19 6.95e-22]]
# [1,   180] segmentation loss: 0.137; discrimination loss: 0.217
# valid:  [[1. 1. 1.]] ; fake:  [[1.58e-07 4.42e-09 2.19e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[1. 1. 1.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.75 1.   1.  ]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.78e-02 5.71e-08 9.94e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.07e-09 1.07e-09 1.45e-10]]
# valid:  [[2.88e-23 9.67e-01 1.00e+00]] ; fake:  [[2.55e-21 5.72e-18 4.43e-20]]
# valid:  [[5.22e-09 1.30e-28 8.75e-11]] ; fake:  [[2.33e-29 1.47e-29 1.49e-26]]
# valid:  [[1.   0.99 0.99]] ; fake:  [[4.67e-26 3.11e-29 3.84e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.29e-22 4.59e-23 7.88e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.52e-24 3.14e-24 1.32e-21]]
# [1,   190] segmentation loss: 0.127; discrimination loss: 10.246
# valid:  [[1. 1. 1.]] ; fake:  [[2.76e-21 8.82e-23 3.84e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.86e-13 2.27e-20 1.12e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.17e-20 1.93e-19 5.09e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.80e-07 4.18e-08 3.40e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.38e-11 5.31e-17 3.12e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.64e-12 8.80e-11 2.48e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.69e-13 1.59e-08 1.26e-07]]
# valid:  [[1.00e+00 8.55e-10 9.99e-01]] ; fake:  [[2.94e-01 4.22e-09 4.65e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.59e-03 1.35e-06 2.73e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.99 0.58 0.89]]
# [1,   200] segmentation loss: 0.123; discrimination loss: 0.963
# [1,   200] validation loss(seg): 0.919; validation loss(disc): 0.062
# valid:  [[1. 1. 1.]] ; fake:  [[1.94e-06 2.23e-07 3.33e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.05e-15 5.80e-14 2.35e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.88e-19 2.19e-23 1.03e-22]]
# valid:  [[1.   1.   0.02]] ; fake:  [[7.64e-20 1.07e-19 9.08e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.11e-23 3.73e-24 3.63e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.88e-22 7.55e-21 1.92e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.16e-21 3.10e-20 1.56e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.28e-18 1.15e-18 8.54e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.61e-15 2.28e-15 3.48e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.63e-15 1.17e-14 8.38e-15]]
# [1,   210] segmentation loss: 0.120; discrimination loss: 0.134
# valid:  [[1. 1. 1.]] ; fake:  [[5.88e-11 4.63e-13 1.77e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.83e-09 1.17e-08 3.72e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.68e-04 8.83e-04 5.54e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.19e-01 5.26e-02 1.20e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.31e-05 2.84e-02 6.46e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.45e-08 2.49e-07 8.74e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.84e-15 1.31e-09 1.91e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.22e-12 2.77e-14 4.60e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.58e-12 1.03e-06 1.76e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.59e-01 9.71e-01 1.99e-18]]
# [1,   220] segmentation loss: 0.110; discrimination loss: 0.207
# valid:  [[1. 1. 1.]] ; fake:  [[2.84e-11 6.33e-11 2.44e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.68e-22 5.03e-24 5.80e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.75e-34 3.32e-35 3.46e-37]]
# valid:  [[1.00e+00 2.01e-07 1.68e-03]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.69e-37 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.95e-36 1.66e-30 8.08e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.55e-19 2.41e-20 1.49e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.17e-13 7.50e-16 6.84e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.35e-04 5.18e-07 1.90e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.01 0.01 0.02]]
# [1,   230] segmentation loss: 0.102; discrimination loss: 0.728
# valid:  [[1. 1. 1.]] ; fake:  [[0.03 0.02 1.  ]]
# valid:  [[1.00e+00 1.00e+00 1.27e-24]] ; fake:  [[3.88e-02 1.66e-04 1.85e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.52e-15 1.69e-09 1.00e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.79e-16 1.00e+00 3.05e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.74e-01 1.68e-04 1.27e-06]]
# valid:  [[1.00e+00 1.00e+00 9.97e-31]] ; fake:  [[2.02e-08 1.30e-12 6.15e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.11e-13 1.01e-12 1.20e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.70e-18 4.13e-18 2.56e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.29e-26 2.33e-25 7.36e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.09e-24 3.25e-27 1.27e-29]]
# [1,   240] segmentation loss: 0.096; discrimination loss: 4.727
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-31 1.13e-24 1.75e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.35e-28 2.99e-37 2.09e-38]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.05e-38 2.16e-38 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 1.15e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.82e-39 0.00e+00 1.29e-37]]
# valid:  [[1.00e+00 9.94e-01 6.00e-04]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 3.83e-39 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.59e-25 3.95e-34 4.28e-34]]
# [1,   250] segmentation loss: 0.085; discrimination loss: 0.248
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-30 4.22e-30 1.35e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.33e-25 2.56e-22 2.18e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.35e-24 6.57e-17 3.36e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.98e-14 5.91e-18 6.62e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.06e-10 5.91e-20 3.66e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.96e-04 4.77e-05 2.60e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.38e-30 3.50e-24 9.49e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 1.17e-03 3.64e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.41e-37 1.13e-12 6.60e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.52e-20 3.58e-13 3.11e-19]]
# [1,   260] segmentation loss: 0.087; discrimination loss: 0.385
# valid:  [[1. 0. 1.]] ; fake:  [[1.65e-23 0.00e+00 7.12e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.61e-30 2.69e-30 2.53e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.36e-36 1.20e-28 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.0e+00 0.0e+00 9.5e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[0.98 0.94 0.96]] ; fake:  [[0. 0. 0.]]
# valid:  [[0.09 1.   0.03]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.88e-38 0.00e+00]]
# [1,   270] segmentation loss: 0.079; discrimination loss: 3.533
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.10e-28 9.16e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.52e-11 0.00e+00 5.74e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.77e-13 3.75e-01 1.47e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.   1.   0.51]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 4.32e-21 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1. 1. 1.]]
# valid:  [[1. 1. 1.]] ; fake:  [[1. 1. 1.]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 5.51e-04 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.06e-36 6.06e-35 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 1.53e-38 1.00e+00]]
# [1,   280] segmentation loss: 0.075; discrimination loss: 47.040
# valid:  [[1. 1. 1.]] ; fake:  [[3.29e-39 1.00e+00 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.75e-01 2.57e-36 9.85e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.19e-20 2.82e-22 1.84e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.21e-34 3.06e-32 0.00e+00]]
# valid:  [[9.45e-01 7.17e-06 4.96e-02]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.11e-38 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.80e-31 0.00e+00 5.13e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.52e-31 6.04e-36 0.00e+00]]
# [1,   290] segmentation loss: 0.072; discrimination loss: 4.462
# valid:  [[1. 1. 1.]] ; fake:  [[1.82e-20 9.65e-17 1.66e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.70e-21 2.23e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.35e-27 7.95e-30 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.88e-21 6.89e-25 1.22e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.16e-11 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.29e-15 0.00e+00 2.25e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.84e-15 0.00e+00 7.47e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 3.64e-05 1.09e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.63e-35 1.39e-37 4.36e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.17e-16 2.94e-26 5.37e-04]]
# [1,   300] segmentation loss: 0.066; discrimination loss: 0.000
# [1,   300] validation loss(seg): 0.723; validation loss(disc): 1.372
# valid:  [[1. 1. 1.]] ; fake:  [[9.19e-18 0.00e+00 2.10e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.75e-25 1.78e-25 9.19e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.19e-16 3.99e-02 2.50e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.99e-01 0.00e+00 8.81e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.03e-34 6.75e-21 1.36e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.61e-22 0.00e+00 5.70e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.67e-34 1.93e-34 8.66e-34]]
# valid:  [[1.   1.   0.41]] ; fake:  [[0. 0. 0.]]
# valid:  [[0. 1. 1.]] ; fake:  [[0.00e+00 3.79e-28 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.59e-32 0.00e+00]]
# [1,   310] segmentation loss: 0.059; discrimination loss: 3.613
# valid:  [[1. 1. 1.]] ; fake:  [[2.33e-35 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.04e-33 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.45e-37 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-38 2.42e-28 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.21e-37 0.00e+00 5.43e-29]]
# valid:  [[0. 1. 1.]] ; fake:  [[0.00e+00 2.56e-37 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 1.46e-37]]
# [1,   320] segmentation loss: 0.063; discrimination loss: 3.333
# valid:  [[1. 1. 1.]] ; fake:  [[8.98e-39 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.21e-36 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.95e-37 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.34e-39 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 5.32e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.68e-31 1.05e-36 7.21e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.92e-23 0.00e+00 1.01e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.77e-32 4.34e-28 0.00e+00]]
# [1,   330] segmentation loss: 0.056; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.34e-33 4.52e-20 7.03e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 3.98e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.40e-36 4.87e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.5e-32 0.0e+00 0.0e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.44e-28 5.17e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-33 1.87e-26 1.17e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.02e-25 1.04e-14 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 3.59e-24 2.22e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 5.81e-22 5.21e-32]]
# [1,   340] segmentation loss: 0.054; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.43e-12 0.00e+00 2.24e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.85e-36 4.72e-35 5.65e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.12e-27 3.47e-30 2.30e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.53e-16 1.55e-32 4.26e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 5.28e-31 6.43e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.93e-16 1.78e-32 1.21e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.70e-29 0.00e+00 3.03e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.0e+00 0.0e+00 7.4e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.31e-35 0.00e+00 1.39e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.49e-39 1.17e-12 0.00e+00]]
# [1,   350] segmentation loss: 0.049; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.81e-29 1.07e-30 7.97e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.09e-18 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.08e-29 3.51e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 7.84e-22 1.47e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.01e-18 2.34e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.23e-34 1.11e-27 1.92e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.04e-25 7.47e-20 1.38e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.09e-15 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.e+00 8.e-19 0.e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.08e-20 2.77e-36 5.24e-34]]
# [1,   360] segmentation loss: 0.052; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.57e-20 1.87e-23 1.63e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.78e-22 0.00e+00 5.82e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 3.06e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.83e-15 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.86e-18 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.01e-29 8.83e-25 4.29e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.59e-26 4.31e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.88e-25 0.00e+00 2.14e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.36e-20 2.30e-18 4.45e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.85e-39 0.00e+00 7.55e-15]]
# [1,   370] segmentation loss: 0.043; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 8.38e-25 7.90e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.71e-37 0.00e+00 1.35e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.11e-21 9.58e-12 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.62e-33 9.50e-10 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.95e-13 8.27e-32 4.42e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.80e-15 1.36e-38 4.62e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.55e-27 6.10e-21 4.97e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.25e-29 1.19e-28 1.07e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.06e-10 7.23e-25 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.78e-18 0.00e+00]]
# [1,   380] segmentation loss: 0.048; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[5.79e-13 1.73e-10 1.50e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.44e-30 1.31e-32 1.76e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.56e-29 2.43e-33 8.90e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.53e-15 2.20e-27 2.09e-37]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.17e-37 3.14e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.97e-13 0.00e+00 7.64e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.41e-18 4.35e-14 7.99e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 6.19e-11 1.02e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.94e-25 5.18e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.53e-08 2.55e-18]]
# [1,   390] segmentation loss: 0.041; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[6.67e-11 2.09e-15 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.41e-32 7.03e-11]]
# valid:  [[1. 1. 0.]] ; fake:  [[0.00e+00 4.82e-13 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.38e-13 1.17e-09 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.81e-11 0.00e+00 4.70e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.72e-14 1.10e-19 1.22e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 9.72e-08 7.23e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.42e-25 7.42e-23 8.35e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.19e-13 0.00e+00 5.40e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.06e-09 8.56e-17]]
# [1,   400] segmentation loss: 0.038; discrimination loss: 3.333
# [1,   400] validation loss(seg): 0.540; validation loss(disc): 1.445
# valid:  [[1. 1. 1.]] ; fake:  [[6.87e-30 3.03e-10 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.57e-20 1.04e-07 7.32e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.58e-23 3.41e-13 3.97e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.36e-08 6.63e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.53e-06 2.37e-27 8.31e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 7.13e-32 4.60e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.15e-19 2.14e-10 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 6.34e-14 2.08e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.10e-27 7.99e-10 4.48e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.68e-16 8.39e-06 0.00e+00]]
# [1,   410] segmentation loss: 0.035; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.23e-24 5.62e-27 2.45e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.20e-23 6.47e-22 4.60e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-38 5.88e-09 5.83e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.66e-17 0.00e+00 3.49e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.31e-22 0.00e+00 1.76e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.62e-16 2.26e-11 1.11e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.00e-11 0.00e+00 3.28e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.20e-16 0.00e+00 6.21e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.85e-19 2.58e-12 2.97e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.03e-21 6.48e-28 0.00e+00]]
# [1,   420] segmentation loss: 0.042; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.18e-18 1.86e-21 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.32e-17 9.79e-26 6.89e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.52e-29 1.11e-33 3.76e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 2.25e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.53e-32 1.41e-10 1.28e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.22e-32 0.00e+00 1.63e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-09 8.90e-29 5.62e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.2e-10 0.0e+00 1.7e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.02e-29 0.00e+00 2.17e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.06e-16 2.01e-19 6.67e-24]]
# [1,   430] segmentation loss: 0.036; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.63e-08 1.78e-14 1.11e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.74e-25 2.43e-15 3.56e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.06e-08 4.53e-31 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.68e-37 9.66e-09 5.27e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.92e-28 7.98e-27 2.39e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.92e-16 9.81e-31 3.65e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.46e-10 1.69e-07 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.10e-23 1.19e-14 2.86e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.47e-12 0.00e+00 1.88e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.64e-16 0.00e+00 8.56e-20]]
# [1,   440] segmentation loss: 0.030; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[7.23e-14 5.80e-07 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.29e-10 0.00e+00 6.40e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.99e-22 6.45e-12 5.57e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.43e-15 9.09e-24 6.82e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.17e-24 1.01e-07 8.65e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.42e-16 9.75e-29 2.70e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.97e-25 1.10e-08 1.44e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.99e-29 3.33e-27 9.98e-01]]
# valid:  [[1.00e+00 3.86e-12 1.00e+00]] ; fake:  [[1.09e-27 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.59e-33 8.98e-35 8.41e-31]]
# [1,   450] segmentation loss: 0.031; discrimination loss: 1.080
# valid:  [[1. 1. 1.]] ; fake:  [[9.80e-22 0.00e+00 8.76e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.24e-13 0.00e+00 1.16e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.38e-34 5.34e-33 1.99e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.12e-23 0.00e+00 9.97e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.58e-21 8.90e-18 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.57e-31 4.07e-27 1.03e-31]]
# valid:  [[1.   1.   0.98]] ; fake:  [[1.88e-22 1.48e-30 7.85e-31]]
# valid:  [[0. 1. 1.]] ; fake:  [[4.79e-32 1.14e-19 6.98e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.97e-09 5.03e-23 1.32e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.84e-06 9.99e-01 9.91e-01]]
# [1,   460] segmentation loss: 0.028; discrimination loss: 0.606
# valid:  [[1. 1. 1.]] ; fake:  [[2.04e-26 0.00e+00 5.30e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.20e-34 7.89e-25 2.02e-31]]
# valid:  [[0.09 1.   1.  ]] ; fake:  [[3.25e-31 1.76e-36 1.27e-38]]
# valid:  [[0.99 0.01 1.  ]] ; fake:  [[1.63e-34 1.09e-35 6.14e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 8.74e-22 2.37e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.60e-18 4.94e-15 1.56e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.66e-02 8.97e-01 1.32e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 1.07e-26 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.00e-29 7.51e-02 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.   0.99 0.02]]
# [1,   470] segmentation loss: 0.027; discrimination loss: 13.807
# valid:  [[1. 1. 1.]] ; fake:  [[3.29e-16 1.45e-13 6.12e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.34e-12 8.77e-17 1.76e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.36e-12 4.46e-23 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.30e-35 9.30e-31 1.49e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.8e-33 0.0e+00 0.0e+00]]
# valid:  [[4.79e-06 1.00e+00 1.00e+00]] ; fake:  [[8.6e-39 0.0e+00 0.0e+00]]
# valid:  [[1.   0.91 1.  ]] ; fake:  [[6.42e-26 4.39e-29 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.98e-36 4.57e-32 1.98e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.05e-26 0.00e+00 6.39e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.53e-16 2.21e-11 7.33e-36]]
# [1,   480] segmentation loss: 0.027; discrimination loss: 0.412
# valid:  [[1. 1. 1.]] ; fake:  [[1.71e-07 8.62e-28 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.11e-06 5.91e-27 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.78e-01 5.17e-17 1.00e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.29e-28 1.14e-06 1.68e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.17e-19 4.78e-18 3.75e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.96e-19 5.70e-26 3.23e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.37e-25 1.10e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.04e-24 0.00e+00 2.18e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.65e-35 1.21e-34 4.95e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 3.16e-27 2.35e-35]]
# [1,   490] segmentation loss: 0.023; discrimination loss: 0.070
# valid:  [[1. 1. 1.]] ; fake:  [[1.08e-37 1.55e-36 7.45e-38]]
# valid:  [[1.   1.   0.99]] ; fake:  [[0.00e+00 5.44e-36 7.62e-37]]
# valid:  [[9.44e-01 3.44e-08 1.00e+00]] ; fake:  [[8.04e-36 3.21e-37 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.49e-37 0.00e+00 3.26e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.52e-14 2.42e-30 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.94e-18 6.57e-16 2.48e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.66e-09 2.98e-17 9.41e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.74e-28 4.34e-01 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.50e-20 1.49e-09 3.65e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.88e-31 5.16e-33 4.42e-28]]
# [1,   500] segmentation loss: 0.023; discrimination loss: 1.060
# [1,   500] validation loss(seg): 0.398; validation loss(disc): 1.333
# valid:  [[1. 1. 1.]] ; fake:  [[7.84e-30 0.00e+00 9.26e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.57e-34 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.41e-35 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.0e+00 1.9e-32 0.0e+00]]
# valid:  [[0.   0.19 0.86]] ; fake:  [[0.00e+00 0.00e+00 8.76e-39]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 4.99e-37 3.05e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.00e-28 0.00e+00 2.59e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.80e-22 0.00e+00 1.16e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.89e-21 8.16e-38 1.82e-21]]
# [1,   510] segmentation loss: 0.025; discrimination loss: 3.393
# valid:  [[1. 1. 1.]] ; fake:  [[8.83e-11 5.15e-36 6.09e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.23e-38 9.37e-36 7.79e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.18e-13 4.39e-22 1.55e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.90e-01 4.22e-23 1.85e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.22e-14 5.20e-10 4.07e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.88e-18 4.02e-20 3.54e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.18e-13 1.50e-35 8.93e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.23e-11 1.19e-10 2.75e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.21e-08 1.66e-29 9.91e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.86e-16 2.11e-28 1.83e-22]]
# [1,   520] segmentation loss: 0.023; discrimination loss: 0.164
# valid:  [[1. 1. 1.]] ; fake:  [[3.32e-28 7.75e-38 2.65e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.04e-29 7.10e-37 2.81e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.78e-35 4.07e-35 1.23e-38]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.56e-34 1.43e-38]]
# valid:  [[1.00e+00 1.00e+00 1.15e-07]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 0.00e+00 7.98e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.09e-34 7.38e-36 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 2.73e-37 2.23e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.35e-26 3.98e-39 5.85e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.66e-32 8.70e-29 1.33e-28]]
# [1,   530] segmentation loss: 0.025; discrimination loss: 0.533
# valid:  [[1. 1. 1.]] ; fake:  [[2.58e-24 1.02e-22 1.80e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.26e-18 2.00e-35 1.34e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.35e-25 7.16e-23 2.25e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.52e-25 6.73e-11 3.37e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.21e-23 1.78e-07 7.03e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.27e-14 5.32e-26 3.40e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.00e-12 1.56e-17 3.27e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.64e-08 6.33e-15 8.91e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.37e-21 6.94e-08 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.59e-34 1.94e-17 4.90e-10]]
# [1,   540] segmentation loss: 0.020; discrimination loss: 0.308
# valid:  [[1. 1. 1.]] ; fake:  [[1.50e-18 0.00e+00 8.02e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.14e-27 2.18e-25 1.52e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.08e-30 1.55e-32 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.95e-36 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.57e-35 0.00e+00 1.06e-29]]
# valid:  [[1.00e+00 1.00e+00 7.81e-08]] ; fake:  [[0.00e+00 0.00e+00 3.78e-37]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.36e-34 0.00e+00 1.48e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.16e-33 1.72e-36 2.07e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.45e-33 5.00e-29 1.24e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.28e-34 0.00e+00 1.52e-22]]
# [1,   550] segmentation loss: 0.022; discrimination loss: 0.546
# valid:  [[1. 1. 1.]] ; fake:  [[5.23e-20 1.43e-38 1.59e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.62e-38 2.42e-19 1.03e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.25e-23 8.88e-37 1.80e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.82e-11 1.46e-16 7.25e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.45e-34 7.00e-13 3.37e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.80e-13 7.63e-15 1.10e-02]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.36e-26 1.02e-15 6.31e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.44e-10 1.24e-18 6.11e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e-21 1.37e-23 9.81e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.05e-22 1.43e-03 2.03e-06]]
# [1,   560] segmentation loss: 0.022; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.73e-31 9.99e-01 3.17e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.52e-33 2.87e-36 6.62e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.58e-15 1.86e-22 1.59e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.85e-27 9.42e-23 6.49e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.44e-35 2.73e-25 4.15e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.24e-32 1.35e-34 1.90e-37]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-34 2.39e-35 2.19e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 6.61e-36 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.69e-36 0.00e+00]]
# valid:  [[0.48 0.9  1.  ]] ; fake:  [[0.00e+00 0.00e+00 1.14e-37]]
# [1,   570] segmentation loss: 0.024; discrimination loss: 0.281
# valid:  [[1. 1. 1.]] ; fake:  [[6.54e-38 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.26e-38 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.77e-33 0.00e+00 2.93e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.14e-35 1.01e-37 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.26e-32 1.77e-35 3.27e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.58e-30 9.28e-30 2.18e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.55e-29 8.56e-31 3.36e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.18e-28 1.02e-28 1.70e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.34e-24 2.56e-35 1.15e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.92e-36 2.71e-26 5.21e-33]]
# [1,   580] segmentation loss: 0.020; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[2.24e-35 4.64e-21 1.01e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.99e-35 2.73e-27 4.12e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.47e-27 3.92e-37 1.35e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.41e-38 3.54e-26 2.27e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.54e-35 2.42e-25 3.32e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.13e-35 6.27e-26 7.17e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.78e-23 2.54e-33 7.69e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.66e-21 3.08e-33 1.49e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.88e-21 2.40e-30 2.73e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.01e-17 1.46e-25 4.03e-24]]
# [1,   590] segmentation loss: 0.023; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[7.75e-28 3.80e-28 1.40e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.08e-28 1.81e-20 1.28e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.49e-20 3.52e-24 7.42e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.87e-19 6.95e-20 4.61e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.90e-15 7.86e-22 2.04e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.35e-24 4.75e-21 2.07e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.88e-20 1.49e-20 2.92e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.83e-24 5.73e-28 4.42e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-32 2.45e-16 1.99e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.65e-13 1.89e-34 2.74e-23]]
# [1,   600] segmentation loss: 0.017; discrimination loss: 0.000
# [1,   600] validation loss(seg): 0.317; validation loss(disc): 1.000
# valid:  [[1. 1. 1.]] ; fake:  [[4.80e-30 8.67e-15 5.54e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.00e-22 4.28e-25 3.21e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.05e-33 4.41e-19 1.13e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.01e-36 3.98e-19 2.51e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.16e-15 1.04e-10 2.44e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.06e-18 4.36e-20 9.34e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.02e-15 2.04e-16 1.80e-23]]
# valid:  [[1.e+00 4.e-33 1.e+00]] ; fake:  [[1.30e-19 3.64e-34 1.51e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.48e-25 1.76e-30 5.95e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.05e-34 1.62e-17 6.08e-15]]
# [1,   610] segmentation loss: 0.020; discrimination loss: 2.487
# valid:  [[1. 1. 1.]] ; fake:  [[7.22e-16 1.30e-32 1.26e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.02e-20 1.63e-16 2.85e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.66e-24 1.83e-22 1.54e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.45e-20 6.17e-16 1.80e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.41e-21 4.78e-27 4.11e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.81e-34 9.37e-22 2.24e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.11e-32 1.59e-23 9.67e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.37e-20 1.28e-29 2.68e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.87e-17 3.38e-30 1.73e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.08e-14 1.76e-34 8.34e-34]]
# [1,   620] segmentation loss: 0.024; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-18 8.17e-27 2.49e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.09e-24 3.59e-24 6.08e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.87e-18 2.26e-23 2.12e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.87e-22 7.80e-31 1.37e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.67e-17 5.85e-24 3.30e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.43e-26 1.26e-24 3.84e-06]]
# valid:  [[1.00e+00 2.53e-34 1.00e+00]] ; fake:  [[1.40e-26 1.94e-34 8.86e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.94e-23 2.24e-22 3.41e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.38e-24 5.91e-19 8.54e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.28e-14 1.16e-21 2.11e-15]]
# [1,   630] segmentation loss: 0.014; discrimination loss: 2.579
# valid:  [[1. 1. 1.]] ; fake:  [[4.14e-17 1.07e-19 3.22e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.48e-24 2.54e-14 2.60e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.43e-27 6.39e-17 4.03e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.41e-25 3.59e-12 2.23e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.98e-24 3.22e-18 4.09e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.12e-18 4.30e-34 2.26e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.51e-22 1.92e-20 3.36e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.01e-28 8.12e-22 5.67e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.85e-25 3.61e-18 4.00e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.88e-24 1.89e-22 4.88e-33]]
# [1,   640] segmentation loss: 0.020; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.37e-15 1.24e-22 2.71e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.63e-25 4.21e-26 1.14e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.50e-24 6.25e-24 4.89e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.66e-21 6.50e-22 7.36e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.59e-25 1.92e-31 6.33e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.19e-28 2.75e-08 2.62e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.14e-32 4.39e-19 4.71e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.14e-26 2.85e-17 2.12e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.01e-35 6.63e-16 1.39e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.26e-34 2.07e-10 8.90e-23]]
# [1,   650] segmentation loss: 0.018; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[8.84e-22 3.11e-12 1.56e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.09e-12 1.94e-21 4.89e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.05e-13 7.56e-06 1.17e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.90e-12 1.88e-10 2.80e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.05e-10 6.64e-08 2.46e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.48e-24 3.19e-19 8.55e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.00e-36 3.32e-18 5.39e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.65e-11 1.47e-20 1.04e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.86e-19 6.29e-36 2.71e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.36e-34 1.08e-22 8.24e-13]]
# [1,   660] segmentation loss: 0.018; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[8.63e-14 4.94e-31 4.82e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.93e-24 4.40e-21 3.74e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.22e-26 3.18e-16 4.07e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.05e-34 2.60e-16 1.59e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.50e-28 2.32e-30 4.10e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.59e-24 5.45e-26 2.19e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.50e-23 3.96e-28 1.64e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.95e-36 2.67e-22 5.49e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.12e-24 5.56e-33 3.58e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.01e-20 1.59e-26 3.06e-29]]
# [1,   670] segmentation loss: 0.020; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.09e-21 1.86e-11 3.26e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.11e-16 1.11e-19 1.56e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.82e-29 4.90e-20 1.40e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.10e-22 5.41e-25 6.52e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.76e-09 3.21e-21 2.14e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.05e-14 1.66e-34 1.87e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.09e-08 6.42e-17 1.01e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.58e-33 1.99e-10 1.27e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.27e-22 2.01e-32 5.64e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.26e-16 1.13e-21 3.69e-17]]
# [1,   680] segmentation loss: 0.021; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.35e-11 4.01e-19 2.32e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.03e-35 2.02e-11 3.83e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.48e-14 2.33e-19 5.65e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.34e-03 1.35e-21 2.00e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.10e-11 1.90e-18 2.16e-35]]
# valid:  [[1.00e+00 6.15e-35 1.00e+00]] ; fake:  [[3.98e-17 8.73e-36 6.46e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.13e-36 6.11e-18 2.47e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.84e-10 1.24e-04 1.69e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.56e-17 4.06e-21 2.08e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.32e-17 3.19e-35 5.96e-10]]
# [1,   690] segmentation loss: 0.019; discrimination loss: 2.626
# valid:  [[1. 1. 1.]] ; fake:  [[5.29e-13 9.65e-22 1.54e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.39e-23 9.87e-01 3.64e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.16e-22 2.52e-11 3.34e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.39e-36 2.08e-26]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.25e-35 1.23e-30 4.53e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.86e-34 8.14e-37 1.39e-38]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.46e-38 1.30e-36 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1.05e-03 1.00e+00 8.96e-04]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.26e-35 3.63e-29 0.00e+00]]
# [1,   700] segmentation loss: 0.018; discrimination loss: 0.608
# [1,   700] validation loss(seg): 0.280; validation loss(disc): 0.959
# valid:  [[1. 1. 1.]] ; fake:  [[1.44e-23 6.01e-24 9.95e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.43e-12 5.21e-04 5.23e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.e+00 1.e-09 1.e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.29e-11 1.53e-11 6.05e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.33e-08 2.40e-22 2.13e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.01e-24 1.15e-20 3.44e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.94e-29 1.74e-23 1.34e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.33e-19 2.77e-32 2.22e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.71e-35 3.98e-27 5.90e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.18e-35 1.99e-33 1.49e-27]]
# [1,   710] segmentation loss: 0.017; discrimination loss: 0.639
# valid:  [[1. 1. 1.]] ; fake:  [[1.29e-34 3.41e-29 1.01e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.39e-36 6.80e-36 1.92e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.15e-30 2.38e-32 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.16e-32 0.00e+00 1.02e-34]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.26e-29 5.44e-37 2.66e-38]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.21e-32 4.30e-32 3.33e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.71e-38 2.81e-32 3.86e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.12e-33 4.82e-34 3.30e-35]]
# valid:  [[1.00e+00 1.00e+00 1.18e-08]] ; fake:  [[0.00e+00 9.56e-27 8.45e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.88e-28 1.01e-21 2.59e-38]]
# [1,   720] segmentation loss: 0.019; discrimination loss: 0.609
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-20 1.36e-22 6.51e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.94e-10 1.97e-27 4.44e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.29e-09 2.45e-19 9.04e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.48e-20 1.18e-10 1.15e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.16e-25 5.01e-10 1.40e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 3.03e-05 3.50e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.   1.   0.29]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.75e-01 1.99e-05 1.00e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.68e-15 5.00e-23 1.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.35e-22 2.19e-18 8.00e-28]]
# [1,   730] segmentation loss: 0.021; discrimination loss: 10.442
# valid:  [[1. 1. 1.]] ; fake:  [[1.77e-13 4.10e-21 2.08e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.93e-29 1.01e-14 4.27e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.57e-26 1.69e-29 1.89e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.73e-26 2.21e-16 8.05e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.39e-32 2.37e-34 1.15e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.18e-28 1.76e-32 1.59e-36]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.75e-37 3.00e-21 6.48e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.14e-33 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.4e-30 0.0e+00 0.0e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.70e-37 2.29e-34 7.13e-36]]
# [1,   740] segmentation loss: 0.016; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.47e-39 8.23e-39 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.51e-35 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0. 0. 0.]]
# valid:  [[1.   1.   0.99]] ; fake:  [[9.21e-34 7.97e-38 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.87e-38 6.11e-39]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-37 0.00e+00 0.00e+00]]
# valid:  [[1.   0.98 1.  ]] ; fake:  [[0. 0. 0.]]
# valid:  [[1.   0.06 0.98]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.50e-39 1.49e-33 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 3.64e-34 0.00e+00]]
# [1,   750] segmentation loss: 0.016; discrimination loss: 0.094
# valid:  [[1. 1. 1.]] ; fake:  [[7.09e-32 5.84e-33 1.90e-33]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.52e-32 0.00e+00 1.54e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.47e-24 8.10e-36 2.67e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.77e-27 3.91e-37 4.57e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.43e-27 2.11e-30 1.46e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.74e-27 8.44e-19 3.86e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.26e-14 3.68e-15 1.87e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.60e-12 1.69e-05 8.34e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.91e-16 2.36e-06 4.88e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.12e-07 3.28e-09 3.05e-01]]
# [1,   760] segmentation loss: 0.012; discrimination loss: 0.012
# valid:  [[1. 1. 1.]] ; fake:  [[3.64e-04 5.83e-26 2.24e-31]]
# valid:  [[1.44e-30 1.00e+00 1.00e+00]] ; fake:  [[3.73e-30 3.60e-04 4.51e-04]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.69e-07 3.55e-08 6.24e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.78e-31 1.56e-15 3.64e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.31e-08 1.11e-29 8.10e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.23e-16 2.35e-06 2.38e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.37e-18 4.24e-04 1.57e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.45e-23 8.34e-14 2.85e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.56e-31 2.46e-18 2.35e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.28e-06 4.69e-18 1.45e-06]]
# [1,   770] segmentation loss: 0.017; discrimination loss: 2.290
# valid:  [[1. 1. 1.]] ; fake:  [[1.88e-16 8.60e-23 1.09e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.92e-19 4.49e-07 2.36e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.99e-14 1.53e-07 2.45e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.03e-09 9.35e-18 2.99e-11]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.20e-12 7.38e-31 4.02e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.18e-15 3.04e-07 1.07e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.70e-15 1.10e-24 3.73e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.57e-29 8.04e-12 1.28e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.38e-26 3.56e-10 2.43e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.29e-06 4.86e-18 8.68e-14]]
# [1,   780] segmentation loss: 0.011; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[5.01e-10 3.33e-31 1.47e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.49e-15 1.37e-12 3.69e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.92e-10 6.91e-20 4.89e-07]]
# valid:  [[9.29e-32 1.00e+00 1.00e+00]] ; fake:  [[3.80e-31 1.29e-09 6.17e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.63e-18 5.70e-16 7.18e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.60e-21 4.62e-17 1.86e-13]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.44e-13 4.38e-28 8.05e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.12e-17 2.94e-27 1.47e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.97e-15 8.60e-06 1.73e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.77e-21 3.17e-08 9.98e-23]]
# [1,   790] segmentation loss: 0.014; discrimination loss: 2.382
# valid:  [[1. 1. 1.]] ; fake:  [[5.56e-27 1.37e-12 7.05e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.47e-18 1.07e-26 1.39e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.03e-24 2.78e-16 2.87e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.17e-17 2.39e-13 1.98e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.52e-10 7.34e-19 1.67e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.38e-09 5.23e-15 2.86e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.03e-27 4.40e-15 5.17e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.89e-14 1.42e-26 1.90e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.72e-16 4.66e-12 3.18e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.73e-18 1.82e-12 5.89e-15]]
# [1,   800] segmentation loss: 0.012; discrimination loss: 0.000
# [1,   800] validation loss(seg): 0.220; validation loss(disc): 0.909
# valid:  [[1. 1. 1.]] ; fake:  [[8.40e-13 2.84e-11 9.18e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.95e-03 5.44e-07 1.94e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.90e-04 2.67e-32 4.22e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.36e-02 1.21e-24 1.25e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.88e-10 1.21e-29 3.36e-03]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.61e-12 3.20e-14 3.19e-08]]
# valid:  [[1.00e+00 6.74e-14 1.00e+00]] ; fake:  [[6.74e-31 2.57e-28 1.36e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.77e-15 5.54e-20 5.20e-31]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.02e-17 4.11e-32 7.27e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.06e-21 4.51e-15 3.59e-15]]
# [1,   810] segmentation loss: 0.016; discrimination loss: 1.012
# valid:  [[1. 1. 1.]] ; fake:  [[1.30e-21 5.35e-19 2.65e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.76e-15 2.07e-11 1.23e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.26e-05 1.38e-31 4.21e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.42e-15 2.09e-21 3.38e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.22e-29 2.77e-27 4.69e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.05e-27 2.78e-17 9.05e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.07e-30 4.64e-17 5.34e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.27e-31 7.00e-24 6.99e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.04e-25 2.20e-11 2.37e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.26e-20 1.91e-08 2.09e-21]]
# [1,   820] segmentation loss: 0.019; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.95e-10 2.89e-18 7.38e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.90e-12 3.59e-15 7.81e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.35e-12 4.36e-31 4.28e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.43e-20 6.38e-13 1.22e-07]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.72e-07 5.59e-19 5.22e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.93e-07 3.50e-13 3.00e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.59e-10 6.61e-08 3.00e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.08e-18 1.32e-04 9.33e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.61e-04 1.92e-24 4.53e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.94e-11 6.55e-11 6.75e-06]]
# [1,   830] segmentation loss: 0.009; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.04e-14 2.52e-06 5.97e-25]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.84e-22 2.90e-04 1.77e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.85e-10 8.67e-30 8.10e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.49e-11 2.90e-09 3.15e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.99e-17 1.33e-19 1.09e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.07e-18 9.76e-05 2.36e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.35e-29 5.04e-13 2.77e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.01e-08 3.94e-31 4.17e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.05e-09 3.83e-20 7.11e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.21e-15 6.70e-08 2.44e-19]]
# [1,   840] segmentation loss: 0.013; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.97e-12 5.70e-14 5.25e-12]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.36e-14 1.17e-31 5.46e-19]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.84e-07 3.02e-13 1.50e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.38e-10 9.86e-13 1.92e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.06e-13 2.04e-20 5.38e-17]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.38e-03 4.68e-10 2.11e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.56e-30 8.47e-10 1.10e-14]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.62e-18 3.95e-06 2.44e-16]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.67e-13 5.48e-12 6.17e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.33e-13 9.44e-17 2.23e-08]]
# [1,   850] segmentation loss: 0.008; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[3.33e-32 8.99e-12 4.83e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.12e-11 2.57e-20 1.63e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.08e-14 1.64e-25 6.44e-28]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.43e-20 3.83e-09 7.96e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.45e-17 2.36e-18 1.71e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.00e+00 1.14e-29 2.69e-15]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.20e-19 3.62e-32 2.81e-20]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.61e-30 1.65e-27 9.01e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.74e-29 2.99e-29 6.01e-35]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.30e-34 2.22e-30 3.68e-30]]
# [1,   860] segmentation loss: 0.014; discrimination loss: 0.367
# valid:  [[1. 1. 1.]] ; fake:  [[2.06e-33 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.02e-39 4.36e-35 1.26e-38]]
# valid:  [[1. 1. 1.]] ; fake:  [[0.00e+00 1.53e-37 0.00e+00]]
# valid:  [[0.97 1.   0.98]] ; fake:  [[0.00e+00 6.85e-38 0.00e+00]]
# valid:  [[0.24 0.92 1.  ]] ; fake:  [[0. 0. 0.]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.91e-38 0.00e+00 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.60e-31 5.72e-32 0.00e+00]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.47e-37 1.10e-32 5.62e-37]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.28e-31 3.17e-31 2.90e-29]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.42e-33 7.35e-30 1.49e-30]]
# [1,   870] segmentation loss: 0.010; discrimination loss: 0.053
# valid:  [[1. 1. 1.]] ; fake:  [[2.08e-26 1.27e-26 1.57e-30]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.93e-26 4.91e-23 1.13e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.71e-24 3.03e-23 2.40e-23]]
# valid:  [[1. 1. 1.]] ; fake:  [[8.32e-34 9.90e-23 8.54e-27]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.04e-20 1.83e-20 1.88e-22]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.34e-16 2.38e-16 1.46e-18]]
# valid:  [[1. 1. 1.]] ; fake:  [[2.21e-13 5.17e-23 2.68e-24]]
# valid:  [[1. 1. 1.]] ; fake:  [[5.81e-30 4.91e-14 3.65e-21]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.94e-23 2.02e-07 6.84e-32]]
# valid:  [[1. 1. 1.]] ; fake:  [[4.38e-08 2.38e-30 1.14e-16]]
# [1,   880] segmentation loss: 0.010; discrimination loss: 0.000
# valid:  [[1. 1. 1.]] ; fake:  [[1.54e-15 3.48e-13 6.01e-10]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.16e-11 4.92e-08 4.10e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[3.46e-17 2.38e-15 7.44e-08]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.16e-06 5.18e-09 3.04e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.78e-07 4.93e-19 8.55e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[6.78e-08 2.37e-11 2.27e-06]]
# valid:  [[1. 1. 1.]] ; fake:  [[1.44e-17 4.29e-09 1.17e-05]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.88e-03 1.12e-06 2.52e-09]]
# valid:  [[1. 1. 1.]] ; fake:  [[7.40e-15 9.30e-11 6.73e-01]]
# valid:  [[1. 1. 1.]] ; fake:  [[9.52e-16 3.25e-08 8.53e-07]]
# [1,   890] segmentation loss: 0.007; discrimination loss: 0.038
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

PATH = os.path.expanduser("~/workspace/us_robot/unet_gan_usseg.pth")
net = UNet(init_features=32).to(device)
net.load_state_dict(torch.load(PATH))
net = net.eval()

# %%
test_dir = os.path.expanduser("~/workspace/us_robot/DataSet/realDataSet/linear/vessel_neck")
pred_dir = os.path.expanduser("~/workspace/us_robot/DataSet/realDataSet/linear/vessel_pred")

testset_list = os.listdir(test_dir)
resize_to=None
transform_image = transforms.Compose([
    #transforms.Resize(resize_to),
    transforms.ToTensor(),
    transforms.Normalize(0.5,0.5) #Division by 255 is done, when the transformation assumes an image.
    ])
transform_label = transforms.Compose([
    #transforms.Resize(resize_to),
    transforms.ToTensor()
    ])
invtransform_label = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.Resize([1000,500])
    ])

for sample in testset_list:
    image_path = os.path.join(test_dir,sample)
    label_path = os.path.join(pred_dir,sample)
    
    img = Image.open(image_path).convert("L")
    img = transform_image(img)
    img = img.to(device)
    img = img.unsqueeze(0)
    #label = Image.open(label_path)
    #label = transform_label(label).to(device)
    #label = label.unsqueeze(0)
    
    
    with torch.no_grad():
        pred = net(img)
    
    #DiceIndex = (1 - DiceLoss(pred,label)).cpu().item()

    pred = invtransform_label(pred.cpu().squeeze(0))
    #fname = "pred%.2f.png"%DiceIndex
    fname = sample
    sav_path = os.path.join(pred_dir,fname)
    pred.save(sav_path)

# %%
test_dir = os.path.expanduser("~/workspace/us_robot/DataSet/SimRealDatasetTest")
testset_list = os.listdir(test_dir)
resize_to=None
transform_image = transforms.Compose([
    #transforms.Resize(resize_to),
    transforms.ToTensor(),
    transforms.Normalize(0.5,0.5) #Division by 255 is done, when the transformation assumes an image.
    ])
transform_label = transforms.Compose([
    #transforms.Resize(resize_to),
    transforms.ToTensor()
    ])
invtransform_label = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.Resize([1000,500])
    ])
for sample in testset_list:
    image_path = os.path.join(test_dir,sample,"image.png")
    label_path = os.path.join(test_dir,sample,"label.png")
    
    img = Image.open(image_path)
    img = transform_image(img)
    img = img.to(device)
    img = img.unsqueeze(0)
    label = Image.open(label_path)
    label = transform_label(label).to(device)
    label = label.unsqueeze(0)
    
    
    with torch.no_grad():
        pred = net(img)
    
    DiceIndex = (1 - DiceLoss(pred,label)).cpu().item()

    pred = invtransform_label(pred.cpu().squeeze(0))
    fname = "pred%.2f.png"%DiceIndex
    sav_path = os.path.join(test_dir,sample,fname)
    pred.save(sav_path)
